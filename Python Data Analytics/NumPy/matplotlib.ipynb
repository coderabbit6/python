# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])

# %%
plt.plot([1,3,5,7])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
plt.axis([0,5,0,20])
plt.title('My first plot')
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
plt.axis([0,5,0,20])
plt.title('My second plot')
plt.plot([1,4,9,16],'r')

# %%
import math
import numpy as np
t = np.arange(0,2.5,0.1)
y1 = map(math.sin,math.pi*t)
y2 = map(math.sin,math.pi*t+math.pi/2)
y3 = map(math.sin,math.pi*t-math.pi/2)
plt.plot(t,y1,'b*',t,y2,'g^',t,y3,'ys')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\matplotlib\units.py in get_converter(self, x)
#     168                 # get_converter
# --> 169                 if not np.all(xravel.mask):
#     170                     # some elements are not masked
#
# AttributeError: 'numpy.ndarray' object has no attribute 'mask'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-c9326cac346a> in <module>
#       5 y2 = map(math.sin,math.pi*t+math.pi/2)
#       6 y3 = map(math.sin,math.pi*t-math.pi/2)
# ----> 7 plt.plot(t,y1,'b*',t,y2,'g^',t,y3,'ys')
#
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']#用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False#用来正常显示负号

x = np.linspace(0, 10, 1000)
y = np.sin(x) + 1
z = np.cos(x ** 2) + 1

plt.figure(figsize = (8, 4))
plt.plot(x,y,label='$\sin x+1$', color = 'red', linewidth = 2)
plt.plot(x,z,'b--',label='$\cos x^2+1$')
plt.xlabel('Time(s)')
plt.ylabel('Volt')
plt.title('A Sample Example')
plt.ylim(0,2.2)
plt.xlim(0,10)
plt.legend(loc='best')

# %%
plt.plot([1,2,3,43,2,7,6,7,3],linewidth = 3.0)  #设置线宽

# %%
## 处理多个Figure和Axes对象
- 使用plt.subplt(211)等设置画布分布子图

# %%
t = np.arange(0,5,0.1)
# print(t)
y1 = np.sin(2*np.pi*t)
y2 = np.sin(2*np.pi*t)
plt.subplot(211)
plt.plot(t,y1,'b-.')
plt.subplot(212)
plt.plot(t,y2,'r--')

# %%
t = np.arange(0,1,0.01)
# print(t)
y1 = np.sin(2*np.pi*t)
y2 = np.sin(2*np.pi*t)
plt.subplot(121)
plt.plot(t,y1,'b-.')
plt.subplot(122)
plt.plot(t,y2,'r--')
plt.savefig('my chart.png')

# %%
pop = np.random.randint(0,100,200)
pop
# Out:
# array([52, 51, 13, 16, 86, 74, 71, 47, 14, 18, 10, 92, 48, 33, 87, 15, 40,
#        98,  5, 61, 32, 51, 86, 98, 75, 18, 32, 48, 65, 40, 84, 38, 87, 65,
#        60, 78, 48, 99, 76, 50, 12, 81, 77, 56, 21, 18, 19, 57, 77, 63, 29,
#        19, 31, 87, 27, 99, 99, 93, 14, 58, 45, 47, 90, 81, 56, 88, 88, 20,
#        95, 92, 14, 40, 95,  3, 48, 94,  2, 33, 39, 43, 81, 24, 36, 76, 30,
#        91, 38, 59, 80, 84, 45, 58, 84, 54, 72,  1, 77,  8, 76, 26, 67, 98,
#        28, 23,  0, 67, 24, 24, 23, 14, 37, 84, 72, 92, 73, 93, 68, 81, 50,
#        64, 90, 89, 43, 84, 85, 46, 69, 33, 70, 32, 82, 48, 18, 79, 50, 16,
#        68, 27, 67, 78, 24, 31, 41, 16, 22, 76, 25, 22, 22, 21, 94, 33,  3,
#        33, 78, 87, 93, 81, 59, 19,  4, 33, 54, 95, 78, 92,  6, 50, 52, 41,
#        25, 13, 24, 46, 13, 43, 91,  1, 18, 63, 32, 49, 18,  0, 49, 50, 56,
#        42, 60,  9, 12, 88, 29, 61, 57, 18, 11, 85, 73, 65])

# %%
n,bins,patches = plt.hist(pop,bins = 30)

# %%
index = [0,1,2,3,4]
values = [5,7,4,3,6]
plt.bar(index,values)
# Out:
# <BarContainer object of 5 artists>
